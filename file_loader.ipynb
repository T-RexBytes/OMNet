# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p "/content/drive/MyDrive/BreakHis"

# %%
# !wget -O "/content/drive/MyDrive/BreakHis/BreaKHis_v1.tar.gz" "http://www.inf.ufpr.br/vri/databases/BreaKHis_v1.tar.gz"
# Out:
# --2026-08-12 14:01:04--  http://www.inf.ufpr.br/vri/databases/BreaKHis_v1.tar.gz
# Resolving www.inf.ufpr.br (www.inf.ufpr.br)... 200.17.202.113, 2801:82:80ff:8001:216:ccff:feaa:79
# Connecting to www.inf.ufpr.br (www.inf.ufpr.br)|200.17.202.113|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.inf.ufpr.br/vri/databases/BreaKHis_v1.tar.gz [following]
# --2026-08-12 14:01:05--  https://www.inf.ufpr.br/vri/databases/BreaKHis_v1.tar.gz
# Connecting to www.inf.ufpr.br (www.inf.ufpr.br)|200.17.202.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4273561758 (4.0G) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/BreakHis/BreaKHis_v1.tar.gz’
#
# /content/drive/MyDr 100%[===================>]   3.98G  23.8MB/s    in 2m 55s
#
# 2026-08-12 14:04:01 (23.3 MB/s) - ‘/content/drive/MyDrive/BreakHis/BreaKHis_v1.tar.gz’ saved [4273561758/4273561758]

# %%
# !tar -xzf "/content/drive/MyDrive/BreakHis/BreaKHis_v1.tar.gz" -C "/content/drive/MyDrive/BreakHis/"
